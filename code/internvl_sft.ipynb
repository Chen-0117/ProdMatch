# %%
# !pip install accelerate==0.28.0 bitsandbytes==0.41.0 decord deepspeed \
einops==0.6.1 einops-exts==0.0.4 huggingface_hub imageio numpy opencv-python \
orjson "peft>=0.4.0" pycocoevalcap pyyaml "scikit-learn>=1.2.2" scipy \
sentencepiece==0.1.99 shortuuid tensorboardX termcolor timm==0.9.12 \
tokenizers==0.15.1 "torch>=2" "torchvision>=0.15" tqdm transformers==4.37.2 \
yacs sentence-transformers==2.2.2 flash_attn datasets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 30.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 kB 9.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 7.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 80.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl.metadata (5.3 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 27.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 22.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 70.5 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd "/content/gdrive/MyDrive/ECE1786_project/InternVL-main/internvl_chat"
# Out:
# /content/gdrive/MyDrive/ECE1786_project/InternVL-main/internvl_chat

# %%
# Using 8 GPUs, fine-tune the full LLM, cost about 30G per GPU
# !GPUS=1 PER_DEVICE_BATCH_SIZE=2 sh shell/internvl2.0/2nd_finetune/internvl2_2b_internlm2_1_8b_dynamic_res_2nd_finetune_full.sh
# Out:
# + GPUS=1
# + BATCH_SIZE=2
# + PER_DEVICE_BATCH_SIZE=2
# + GRADIENT_ACC=1
# + pwd
# + export PYTHONPATH=/env/python:/content/gdrive/MyDrive/ECE1786_project/InternVL-main/internvl_chat
# + export MASTER_PORT=34229
# + export TF_CPP_MIN_LOG_LEVEL=3
# + export LAUNCHER=pytorch
# + OUTPUT_DIR=work_dirs/internvl_chat_v2_0/internvl2_2b_internlm2_1_8b_dynamic_res_2nd_finetune_full
# + [ ! -d work_dirs/internvl_chat_v2_0/internvl2_2b_internlm2_1_8b_dynamic_res_2nd_finetune_full ]
# ...

# %%
# Using 2 GPUs, fine-tune the LoRA, cost about 27G per GPU
# !GPUS=1 PER_DEVICE_BATCH_SIZE=2 sh shell/internvl2.0/2nd_finetune/internvl2_2b_internlm2_1_8b_dynamic_res_2nd_finetune_lora.sh
# Out:
# + GPUS=1
# + BATCH_SIZE=2
# + PER_DEVICE_BATCH_SIZE=2
# + GRADIENT_ACC=1
# + pwd
# + export PYTHONPATH=/env/python:/content/gdrive/MyDrive/ECE1786_project/InternVL-main/internvl_chat
# + export MASTER_PORT=34229
# + export TF_CPP_MIN_LOG_LEVEL=3
# + export LAUNCHER=pytorch
# + OUTPUT_DIR=work_dirs/internvl_chat_v2_0/internvl2_2b_internlm2_1_8b_dynamic_res_2nd_finetune_lora
# + [ ! -d work_dirs/internvl_chat_v2_0/internvl2_2b_internlm2_1_8b_dynamic_res_2nd_finetune_lora ]
# ...

# %%
# !PYTHONPATH=/content/gdrive/MyDrive/ECE1786_project/InternVL-main/internvl_chat python tools/merge_lora.py work_dirs/internvl_chat_v2_0/internvl2_2b_internlm2_1_8b_dynamic_res_2nd_finetune_lora work_dirs/internvl_chat_v2_0/internvl_2b_lora_merged
# Out:
# Loading model...
# trainable params: 15,728,640 || all params: 1,904,875,520 || trainable%: 0.8257
# Loading tokenizer...
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Saving model...
# Saving tokenizer...
# Done!

# %%
# Using 2 GPUs, fine-tune the LoRA, cost about 19G per GPU
# !GPUS=1 PER_DEVICE_BATCH_SIZE=2 sh shell/internvl2.0/2nd_finetune/internvl2_4b_phi3_3_8b_dynamic_res_2nd_finetune_lora.sh
# Out:
# + GPUS=1
# + BATCH_SIZE=2
# + PER_DEVICE_BATCH_SIZE=2
# + GRADIENT_ACC=1
# + pwd
# + export PYTHONPATH=/env/python:/content/gdrive/MyDrive/ECE1786_project/InternVL-main/internvl_chat
# + export MASTER_PORT=34229
# + export TF_CPP_MIN_LOG_LEVEL=3
# + export LAUNCHER=pytorch
# + OUTPUT_DIR=work_dirs/internvl_chat_v2_0/internvl2_4b_phi3_3_8b_dynamic_res_2nd_finetune_lora
# + [ ! -d work_dirs/internvl_chat_v2_0/internvl2_4b_phi3_3_8b_dynamic_res_2nd_finetune_lora ]
# ...

# %%
# !PYTHONPATH=/content/gdrive/MyDrive/ECE1786_project/InternVL-main/internvl_chat python tools/merge_lora.py work_dirs/internvl_chat_v2_0/internvl2_4b_phi3_3_8b_dynamic_res_2nd_finetune_lora work_dirs/internvl_chat_v2_0/internvl_4b_lora_merged
# Out:
# Loading model...
# trainable params: 25,165,824 || all params: 3,845,975,040 || trainable%: 0.6543
# Loading checkpoint shards: 100% 2/2 [00:00<00:00,  3.23it/s]
# Loading tokenizer...
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Saving model...
# Saving tokenizer...
# Done!

# %%
# Using 2 GPUs, fine-tune the LoRA, cost about 79G per GPU
# !GPUS=1 PER_DEVICE_BATCH_SIZE=2 sh shell/internvl2.0/2nd_finetune/internvl2_8b_internlm2_7b_dynamic_res_2nd_finetune_lora.sh
# Out:
# + GPUS=1
# + BATCH_SIZE=2
# + PER_DEVICE_BATCH_SIZE=2
# + GRADIENT_ACC=1
# + pwd
# + export PYTHONPATH=/env/python:/content/gdrive/MyDrive/ECE1786_project/InternVL-main/internvl_chat
# + export MASTER_PORT=34229
# + export TF_CPP_MIN_LOG_LEVEL=3
# + export LAUNCHER=pytorch
# + OUTPUT_DIR=work_dirs/internvl_chat_v2_0/internvl2_8b_internlm2_7b_dynamic_res_2nd_finetune_lora
# + [ ! -d work_dirs/internvl_chat_v2_0/internvl2_8b_internlm2_7b_dynamic_res_2nd_finetune_lora ]
# ...

# %%
# !PYTHONPATH=/content/gdrive/MyDrive/ECE1786_project/InternVL-main/internvl_chat python tools/merge_lora.py work_dirs/internvl_chat_v2_0/internvl2_8b_internlm2_7b_dynamic_res_2nd_finetune_lora work_dirs/internvl_chat_v2_0/internvl_8b_lora_merged_new
# Out:
# Loading model...
# trainable params: 37,748,736 || all params: 7,775,531,008 || trainable%: 0.4855
# Loading checkpoint shards: 100% 4/4 [00:01<00:00,  2.30it/s]
# Loading tokenizer...
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Saving model...
# Saving tokenizer...
# Done!
